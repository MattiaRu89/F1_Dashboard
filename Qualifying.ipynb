# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\matti\OneDrive\Desktop\Projects_Analysis\F1\Qualifying.csv')
df
# Out:
#       Unnamed: 0  qualifyId  raceId  driverId  constructorId  number  \
# 0              0          1      18         1              1      22
# 1              1          2      18         9              2       4
# 2              2          3      18         5              1      23
# 3              3          4      18        13              6       2
# 4              4          5      18         2              2       3
# ...          ...        ...     ...       ...            ...     ...
# 9810        9810       9868    1110       848              3      23
# 9811        9811       9869    1110       855             51      24
# 9812        9812       9870    1110       858              3       2
# 9813        9813       9871    1110       817            213       3
# 9814        9814       9872    1110       807            210      27
#
#       position               q1               q2               q3
# 0            1  0 days 01:26:06  0 days 01:25:02  0 days 01:26:07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9815 entries, 0 to 9814
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     9815 non-null   int64
#  1   qualifyId      9815 non-null   int64
#  2   raceId         9815 non-null   int64
#  3   driverId       9815 non-null   int64
#  4   constructorId  9815 non-null   int64
#  5   number         9815 non-null   int64
#  6   position       9815 non-null   int64
#  7   q1             9807 non-null   object
#  8   q2             9815 non-null   object
#  9   q3             9815 non-null   object
# dtypes: int64(7), object(3)
# memory usage: 766.9+ KB

# %%
df.loc[df['q1']=="\\N"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, qualifyId, raceId, driverId, constructorId, number, position, q1, q2, q3]
# Index: []

# %%
df['q1']=df['q1'].replace("\\N",0)
df['q2']=df['q2'].replace("\\N",0)
df['q3']=df['q3'].replace("\\N",0)

# %%
df
# Out:
#       Unnamed: 0  qualifyId  raceId  driverId  constructorId  number  \
# 0              0          1      18         1              1      22
# 1              1          2      18         9              2       4
# 2              2          3      18         5              1      23
# 3              3          4      18        13              6       2
# 4              4          5      18         2              2       3
# ...          ...        ...     ...       ...            ...     ...
# 9810        9810       9868    1110       848              3      23
# 9811        9811       9869    1110       855             51      24
# 9812        9812       9870    1110       858              3       2
# 9813        9813       9871    1110       817            213       3
# 9814        9814       9872    1110       807            210      27
#
#       position               q1               q2               q3
# 0            1  0 days 01:26:06  0 days 01:25:02  0 days 01:26:07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9815 entries, 0 to 9814
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     9815 non-null   int64
#  1   qualifyId      9815 non-null   int64
#  2   raceId         9815 non-null   int64
#  3   driverId       9815 non-null   int64
#  4   constructorId  9815 non-null   int64
#  5   number         9815 non-null   int64
#  6   position       9815 non-null   int64
#  7   q1             9807 non-null   object
#  8   q2             9815 non-null   object
#  9   q3             9815 non-null   object
# dtypes: int64(7), object(3)
# memory usage: 766.9+ KB

# %%
df
# Out:
#       Unnamed: 0  qualifyId  raceId  driverId  constructorId  number  \
# 0              0          1      18         1              1      22
# 1              1          2      18         9              2       4
# 2              2          3      18         5              1      23
# 3              3          4      18        13              6       2
# 4              4          5      18         2              2       3
# ...          ...        ...     ...       ...            ...     ...
# 9810        9810       9868    1110       848              3      23
# 9811        9811       9869    1110       855             51      24
# 9812        9812       9870    1110       858              3       2
# 9813        9813       9871    1110       817            213       3
# 9814        9814       9872    1110       807            210      27
#
#       position               q1               q2               q3
# 0            1  0 days 01:26:06  0 days 01:25:02  0 days 01:26:07
# ...

# %%
df['q1']=df['q1'].str.replace('.',':')
df['q2']=df['q2'].str.replace('.',':')
df['q3']=df['q3'].str.replace('.',':')

# %%
df
# Out:
#       Unnamed: 0  qualifyId  raceId  driverId  constructorId  number  \
# 0              0          1      18         1              1      22
# 1              1          2      18         9              2       4
# 2              2          3      18         5              1      23
# 3              3          4      18        13              6       2
# 4              4          5      18         2              2       3
# ...          ...        ...     ...       ...            ...     ...
# 9810        9810       9868    1110       848              3      23
# 9811        9811       9869    1110       855             51      24
# 9812        9812       9870    1110       858              3       2
# 9813        9813       9871    1110       817            213       3
# 9814        9814       9872    1110       807            210      27
#
#       position               q1               q2               q3
# 0            1  0 days 01:26:06  0 days 01:25:02  0 days 01:26:07
# ...

# %%
df['q2']=df['q2'].fillna(0)
df['q3']=df['q3'].fillna(0)

# %%
df.reset_index(drop=True)
# Out:
#       Unnamed: 0  qualifyId  raceId  driverId  constructorId  number  \
# 0              0          1      18         1              1      22
# 1              1          2      18         9              2       4
# 2              2          3      18         5              1      23
# 3              3          4      18        13              6       2
# 4              4          5      18         2              2       3
# ...          ...        ...     ...       ...            ...     ...
# 9810        9810       9868    1110       848              3      23
# 9811        9811       9869    1110       855             51      24
# 9812        9812       9870    1110       858              3       2
# 9813        9813       9871    1110       817            213       3
# 9814        9814       9872    1110       807            210      27
#
#       position               q1               q2               q3
# 0            1  0 days 01:26:06  0 days 01:25:02  0 days 01:26:07
# ...

# %%
df['q1']=pd.to_timedelta(df['q1'])

# %%
df['q2']=pd.to_timedelta(df['q2'])

# %%
df['q3']=pd.to_timedelta(df['q3'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9815 entries, 0 to 9814
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     9815 non-null   int64
#  1   qualifyId      9815 non-null   int64
#  2   raceId         9815 non-null   int64
#  3   driverId       9815 non-null   int64
#  4   constructorId  9815 non-null   int64
#  5   number         9815 non-null   int64
#  6   position       9815 non-null   int64
#  7   q1             9807 non-null   timedelta64[ns]
#  8   q2             9815 non-null   timedelta64[ns]
#  9   q3             9815 non-null   timedelta64[ns]
# dtypes: int64(7), timedelta64[ns](3)
# memory usage: 766.9 KB

# %%
df
# Out:
#       Unnamed: 0  qualifyId  raceId  driverId  constructorId  number  \
# 0              0          1      18         1              1      22
# 1              1          2      18         9              2       4
# 2              2          3      18         5              1      23
# 3              3          4      18        13              6       2
# 4              4          5      18         2              2       3
# ...          ...        ...     ...       ...            ...     ...
# 9810        9810       9868    1110       848              3      23
# 9811        9811       9869    1110       855             51      24
# 9812        9812       9870    1110       858              3       2
# 9813        9813       9871    1110       817            213       3
# 9814        9814       9872    1110       807            210      27
#
#       position              q1              q2              q3
# 0            1 0 days 01:26:06 0 days 01:25:02 0 days 01:26:07
# ...

# %%
df['q1']=df['q1'].astype(str)
df['q1']=df['q1'].str.split(' ').str[2]

# %%
df['q2']=df['q2'].astype(str)
df['q2']=df['q2'].str.split(' ').str[2]

# %%
df['q3']=df['q3'].astype(str)
df['q3']=df['q3'].str.split(' ').str[2]

# %%
# Out:
#       Unnamed: 0  qualifyId  raceId  driverId  constructorId  number  \
# 0              0          1      18         1              1      22
# 1              1          2      18         9              2       4
# 2              2          3      18         5              1      23
# 3              3          4      18        13              6       2
# 4              4          5      18         2              2       3
# ...          ...        ...     ...       ...            ...     ...
# 9810        9810       9868    1110       848              3      23
# 9811        9811       9869    1110       855             51      24
# 9812        9812       9870    1110       858              3       2
# 9813        9813       9871    1110       817            213       3
# 9814        9814       9872    1110       807            210      27
#
#       position        q1        q2        q3
# 0            1  01:26:06  01:25:02  01:26:07
# 1            2  01:26:01  01:25:03  01:26:09
# ...

# %%
df.to_csv(r'C:\Users\matti\OneDrive\Desktop\Projects_Analysis\F1\qualifying.csv')
