# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\matti\OneDrive\Desktop\Projects_Analysis\F1\results.csv')

# %%
df
# Out:
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 0             1      18         1              1      22     1         1
# 1             2      18         2              2       3     5         2
# 2             3      18         3              3       7     7         3
# 3             4      18         4              4       5    11         4
# 4             5      18         5              1      23     3         5
# ...         ...     ...       ...            ...     ...   ...       ...
# 26075     26081    1110       817            213       3    19        16
# 26076     26082    1110       858              3       2    18        17
# 26077     26083    1110       807            210      27     0        18
# 26078     26084    1110       832              6      55     4         0
# 26079     26085    1110       857              1      81     5         0
#
#       positionText  positionOrder  points  laps      time  milliseconds  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26080 entries, 0 to 26079
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         26080 non-null  int64
#  1   raceId           26080 non-null  int64
#  2   driverId         26080 non-null  int64
#  3   constructorId    26080 non-null  int64
#  4   number           26080 non-null  int64
#  5   grid             26080 non-null  int64
#  6   position         26080 non-null  int64
#  7   positionText     26080 non-null  object
#  8   positionOrder    26080 non-null  int64
#  9   points           26080 non-null  float64
#  10  laps             26080 non-null  int64
#  11  time             26080 non-null  object
#  12  milliseconds     26080 non-null  int64
#  13  fastestLap       26080 non-null  int64
#  14  rank             26080 non-null  int64
#  15  fastestLapTime   26080 non-null  object
#  16  fastestLapSpeed  26080 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['resultId', 'raceId', 'driverId', 'constructorId', 'number', 'grid',
#        'position', 'positionText', 'positionOrder', 'points', 'laps', 'time',
#        'milliseconds', 'fastestLap', 'rank', 'fastestLapTime',
#        'fastestLapSpeed', 'statusId'],
#       dtype='object')

# %%
columns_check=['number', 
       'position', 'positionText', 'positionOrder',  'time',
       'milliseconds', 'fastestLap', 'rank', 'fastestLapTime',
       'fastestLapSpeed']

# %%
df[columns_check]=df[columns_check].replace('\\N',0)

# %%
df
# Out:
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 0             1      18         1              1      22     1         1
# 1             2      18         2              2       3     5         2
# 2             3      18         3              3       7     7         3
# 3             4      18         4              4       5    11         4
# 4             5      18         5              1      23     3         5
# ...         ...     ...       ...            ...     ...   ...       ...
# 26075     26081    1110       817            213       3    19        16
# 26076     26082    1110       858              3       2    18        17
# 26077     26083    1110       807            210      27     0        18
# 26078     26084    1110       832              6      55     4         0
# 26079     26085    1110       857              1      81     5         0
#
#       positionText  positionOrder  points  laps      time  milliseconds  \
# ...

# %%
df['time']=df['time'].str.replace('+',' ')

# %%
df
# Out:
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 0             1      18         1              1      22     1         1
# 1             2      18         2              2       3     5         2
# 2             3      18         3              3       7     7         3
# 3             4      18         4              4       5    11         4
# 4             5      18         5              1      23     3         5
# ...         ...     ...       ...            ...     ...   ...       ...
# 26075     26081    1110       817            213       3    19        16
# 26076     26082    1110       858              3       2    18        17
# 26077     26083    1110       807            210      27     0        18
# 26078     26084    1110       832              6      55     4         0
# 26079     26085    1110       857              1      81     5         0
#
#       positionText  positionOrder  points  laps      time  milliseconds  \
# ...

# %%
df
# Out:
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 0             1      18         1              1      22     1         1
# 1             2      18         2              2       3     5         2
# 2             3      18         3              3       7     7         3
# 3             4      18         4              4       5    11         4
# 4             5      18         5              1      23     3         5
# ...         ...     ...       ...            ...     ...   ...       ...
# 26075     26081    1110       817            213       3    19        16
# 26076     26082    1110       858              3       2    18        17
# 26077     26083    1110       807            210      27     0        18
# 26078     26084    1110       832              6      55     4         0
# 26079     26085    1110       857              1      81     5         0
#
#       positionText  positionOrder  points  laps      time  milliseconds  \
# ...

# %%
df.isna().sum()
# Out:
# resultId           0
# raceId             0
# driverId           0
# constructorId      0
# number             0
# grid               0
# position           0
# positionText       0
# positionOrder      0
# points             0
# laps               0
# time               0
# milliseconds       0
# fastestLap         0
# rank               0
# fastestLapTime     0
# fastestLapSpeed    0
# statusId           0
# dtype: int64

# %%
df['time']=df['time'].str.strip()

# %%
df['time']=df['time'].fillna(0)

# %%
df.to_csv(r'C:\Users\matti\OneDrive\Desktop\Projects_Analysis\F1\results.csv')

# %%
df
# Out:
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 0             1      18         1              1      22     1         1
# 1             2      18         2              2       3     5         2
# 2             3      18         3              3       7     7         3
# 3             4      18         4              4       5    11         4
# 4             5      18         5              1      23     3         5
# ...         ...     ...       ...            ...     ...   ...       ...
# 26075     26081    1110       817            213       3    19        16
# 26076     26082    1110       858              3       2    18        17
# 26077     26083    1110       807            210      27     0        18
# 26078     26084    1110       832              6      55     4         0
# 26079     26085    1110       857              1      81     5         0
#
#       positionText  positionOrder  points  laps      time  milliseconds  \
# ...
