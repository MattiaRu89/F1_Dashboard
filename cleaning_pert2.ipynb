# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from unidecode import unidecode
import os

# %%
df=pd.read_csv(r'C:\Users\matti\OneDrive\Desktop\Projects_Analysis\F1\Dashboard\Tabs_scrap\data_classifications_points.csv')
df
# Out:
#        idrace  driverid forename   surname        full_name         dob  \
# 0           9         1    Lewis  Hamilton   Lewis Hamilton  1985-01-07
# 1         939         1    Lewis  Hamilton   Lewis Hamilton  1985-01-07
# 2         963         1    Lewis  Hamilton   Lewis Hamilton  1985-01-07
# 3        1096         1    Lewis  Hamilton   Lewis Hamilton  1985-01-07
# 4         161         2     Nick  Heidfeld    Nick Heidfeld  1977-05-10
# ...       ...       ...      ...       ...              ...         ...
# 25606    1023       844  Charles   Leclerc  Charles Leclerc  1997-10-16
# 25607    1084       844  Charles   Leclerc  Charles Leclerc  1997-10-16
# 25608    1076       844  Charles   Leclerc  Charles Leclerc  1997-10-16
# 25609    1074       844  Charles   Leclerc  Charles Leclerc  1997-10-16
# 25610    1095       847   George   Russell   George Russell  1998-02-15
#
#       nationality  points  position  positionorder constructors    flags  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25611 entries, 0 to 25610
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   idrace          25611 non-null  int64
#  1   driverid        25611 non-null  int64
#  2   forename        25611 non-null  object
#  3   surname         25611 non-null  object
#  4   full_name       25611 non-null  object
#  5   dob             25611 non-null  object
#  6   nationality     25611 non-null  object
#  7   points          25611 non-null  float64
#  8   position        25611 non-null  int64
#  9   positionorder   25611 non-null  int64
#  10  constructors    25611 non-null  object
#  11  flags           25611 non-null  object
#  12  gp              25611 non-null  object
#  13  circuitid       25611 non-null  int64
#  14  year            25611 non-null  int64
#  15  status          25611 non-null  object
#  16  location        25611 non-null  object
# ...

# %%
df['forename']=df['forename'].apply(unidecode)
df['surname']=df['surname'].apply(unidecode)
df['full_name']=df['full_name'].apply(unidecode)
df['location']=df['location'].apply(unidecode)
df['country']=df['country'].apply(unidecode)

# %%
df
# Out:
#        idrace  driverid forename   surname        full_name         dob  \
# 0           9         1    Lewis  Hamilton   Lewis Hamilton  1985-01-07
# 1         939         1    Lewis  Hamilton   Lewis Hamilton  1985-01-07
# 2         963         1    Lewis  Hamilton   Lewis Hamilton  1985-01-07
# 3        1096         1    Lewis  Hamilton   Lewis Hamilton  1985-01-07
# 4         161         2     Nick  Heidfeld    Nick Heidfeld  1977-05-10
# ...       ...       ...      ...       ...              ...         ...
# 25606    1023       844  Charles   Leclerc  Charles Leclerc  1997-10-16
# 25607    1084       844  Charles   Leclerc  Charles Leclerc  1997-10-16
# 25608    1076       844  Charles   Leclerc  Charles Leclerc  1997-10-16
# 25609    1074       844  Charles   Leclerc  Charles Leclerc  1997-10-16
# 25610    1095       847   George   Russell   George Russell  1998-02-15
#
#       nationality  points  position  positionorder constructors    flags  \
# ...

# %%
df.isna().sum()
# Out:
# idrace            0
# driverid          0
# forename          0
# surname           0
# full_name         0
# dob               0
# nationality       0
# points            0
# position          0
# positionorder     0
# constructors      0
# flags             0
# gp                0
# circuitid         0
# year              0
# status            0
# location          0
# country           0
# order_arriving    0
# cnt_position      0
# dtype: int64

# %%
df['time_race']=df['time_race'].fillna('00:00:00')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\matti\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_race'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['time_race']=df['time_race'].fillna('00:00:00')
#
# ...

# %%
df.isna().sum()
# Out:
# idrace             0
# driverid           0
# forename           0
# surname            0
# full_name          0
# dob                0
# nationality        0
# points             0
# position           0
# positionorder      0
# constructors       0
# flags              0
# gp                 0
# circuitid          0
# year               0
# time_race          0
# fastestlap         0
# fastestlapspeed    0
# status             0
# location           0
# country            0
# dtype: int64

# %%
df
# Out:
#        idrace  driverid   forename     surname         full_name         dob  \
# 0         603       172    Jacques     Laffite   Jacques Laffite  1943-11-21
# 1         511       177       Keke     Rosberg      Keke Rosberg  1948-12-06
# 2         470       117      Alain       Prost       Alain Prost  1955-02-24
# 3         693       400      Chris    Lawrence    Chris Lawrence  1933-07-27
# 4         578       291        Guy      Tunmer        Guy Tunmer  1948-12-01
# ...       ...       ...        ...         ...               ...         ...
# 25606     822       715    Gunther      Bechem    Gunther Bechem  1921-12-21
# 25607     993       842     Pierre       Gasly      Pierre Gasly  1996-02-07
# 25608    1098       858      Logan    Sargeant    Logan Sargeant  2000-12-31
# 25609    1045        20  Sebastian      Vettel  Sebastian Vettel  1987-07-03
# 25610     914       807       Nico  Hulkenberg   Nico Hulkenberg  1987-08-19
#
# ...

# %%
df.to_csv(r'c:\\Users\\matti\\OneDrive\\Desktop\\Projects_Analysis\\F1\\Dashboard\'Data_points_victories.csv')
