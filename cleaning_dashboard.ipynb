# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from unidecode import unidecode
import os

# %%
df=pd.read_csv(r'C:\Users\matti\OneDrive\Desktop\Projects_Analysis\F1\Dashboard\1.csv')
df
# Out:
#           id  driverid  forename     surname          full_name         dob  \
# 0      26080       857     Oscar     Piastri      Oscar Piastri  2001-04-06
# 1      26079       832    Carlos       Sainz       Carlos Sainz  1994-09-01
# 2      26078       807      Nico  Hulkenberg    Nico Hulkenberg  1987-08-19
# 3      26077       858     Logan    Sargeant     Logan Sargeant  2000-12-31
# 4      26076       817    Daniel   Ricciardo   Daniel Ricciardo  1989-07-01
# ...      ...       ...       ...         ...                ...         ...
# 67917      5         5    Heikki  Kovalainen  Heikki Kovalainen  1981-10-19
# 67918      4         4  Fernando      Alonso    Fernando Alonso  1981-07-29
# 67919      3         3      Nico     Rosberg       Nico Rosberg  1985-06-27
# 67920      2         2      Nick    Heidfeld      Nick Heidfeld  1977-05-10
# 67921      1         1     Lewis    Hamilton     Lewis Hamilton  1985-01-07
#
# ...

# %%
df['circuit']=df['circuit'].apply(unidecode)
df['location']=df['location'].apply(unidecode)
df['country']=df['country'].apply(unidecode)

# %%
New_df=df

# %%
New_df
# Out:
#           id  driverid  forename     surname          full_name         dob  \
# 0      26080       857     Oscar     Piastri      Oscar Piastri  2001-04-06
# 1      26079       832    Carlos       Sainz       Carlos Sainz  1994-09-01
# 2      26078       807      Nico  Hulkenberg    Nico Hulkenberg  1987-08-19
# 3      26077       858     Logan    Sargeant     Logan Sargeant  2000-12-31
# 4      26076       817    Daniel   Ricciardo   Daniel Ricciardo  1989-07-01
# ...      ...       ...       ...         ...                ...         ...
# 67917      5         5    Heikki  Kovalainen  Heikki Kovalainen  1981-10-19
# 67918      4         4  Fernando      Alonso    Fernando Alonso  1981-07-29
# 67919      3         3      Nico     Rosberg       Nico Rosberg  1985-06-27
# 67920      2         2      Nick    Heidfeld      Nick Heidfeld  1977-05-10
# 67921      1         1     Lewis    Hamilton     Lewis Hamilton  1985-01-07
#
# ...

# %%
directory=os.getcwd()
directory
# Out:
# 'c:\\Users\\matti\\OneDrive\\Desktop\\Projects_Analysis\\F1\\Dashboard'

# %%
New_df.to_csv(r'c:\\Users\\matti\\OneDrive\\Desktop\\Projects_Analysis\\F1\\Dashboard\'1_F1.csv')
